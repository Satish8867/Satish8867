# %%
## Import the libraries and dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('heart.csv')

# %%
## Display top 5 rows of the dataset
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
## Check the last 5 rows of the dataset
data.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
data.shape ## Find shape of our dataset(Number of rows and columns)
# Out:
# (1025, 14)

# %%
data.info()  ## Get information about our dataset like total number rows and columns, data type of each column and memory requriement
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
data.isnull().sum() ## Check Null Values in the dataset
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
## Check for duplicate data and drop them
data_dup = data.duplicated().any()
print(data_dup)
# Out:
# True

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (302, 14)

# %%
data.describe() ## Get overall statistics about the dataset
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %%
## Draw correlation matrix
plt.figure(figsize=(17,6))
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
## How many people have heart disease, and how many don't have heart disease in this dataset?
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['target'].value_counts()
# Out:
# target
# 1    164
# 0    138
# Name: count, dtype: int64

# %%
sns.countplot(x="target", data=data)
plt.show()

# %%
## Find count of male and female in this dataset
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['sex'].value_counts()
# Out:
# sex
# 1    206
# 0     96
# Name: count, dtype: int64

# %%
sns.countplot(x="sex", data=data)
plt.xticks([0, 1],['Female', 'Male'])
plt.show()

# %%
## Find Gender Distribution according to the target variable
data_no_disease = data[data['target'] == 0]
data_disease = data[data['target'] == 1]

# Create the count plot for 'No-Disease'
sns.countplot(x="sex", data=data_no_disease, color='blue', label='No-Disease', width=0.4)

# Overlay the count plot for 'Disease'
sns.countplot(x="sex", data=data_disease, color='red', label='Disease', width=0.4)

# Customize the x-axis labels (assuming 0 is Male and 1 is Female)
plt.xticks([0, 1], ["Male", "Female"])

# Customize the legend labels
plt.legend(labels=['No-Disease', 'Disease'])

plt.show()

# %%
## Check Age distribution in the dataset
sns.distplot(data['age'],bins=20)
plt.show()
# Out:
# C:\Users\SATISH M\AppData\Local\Temp\ipykernel_8580\4281029158.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['age'],bins=20)
# C:\Users\SATISH M\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
## Check chest pain type.
sns.countplot(x="cp", data=data)
plt.xticks([0,1,2,3],["typical angina","atypical angina","non-anginal pain","asymptomatic"])
plt.xticks(rotation=75)
plt.show()

# %%
## show the chest pain distribution as per target variable.
data_no_disease = data[data['target'] == 0]
data_disease = data[data['target'] == 1]

# Plot for 'No-Disease'
sns.countplot(x="cp", data=data_no_disease, color='blue', label='No-Disease', width=0.4)


# Overlay the plot for 'Disease'
sns.countplot(x="cp", data=data_disease, color='red', label='Disease', width=0.4)

# Customize the legend
plt.legend(title="Condition", labels=["No-Disease", "Disease"])

# Show the plot
plt.show()

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
## Check Resting blood pressure distribuion
data['trestbps'].hist()
# Out:
# <Axes: >

# %%
## compare Resting blood pressure as per sex column
g = sns.FacetGrid(data, hue="sex", aspect=4)
g.map(sns.kdeplot, 'trestbps', fill=True)
plt.legend(labels=['male','Female'])
plt.show()
# Out:
# C:\Users\SATISH M\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\SATISH M\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
## show distribution of serum cholesterol.
data['chol'].hist()
# Out:
# <Axes: >

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
## plot continuos variable
cate_val=[]
cont_val=[]

for column in data.columns:
    if data[column].nunique() <=10:
        cate_val.append(column)
    else:
        cont_val.append(column)

# %%
cate_val
# Out:
# ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']

# %%
cont_val
# Out:
# ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %%
data.hist(cont_val,figsize=(15,6))
plt.tight_layout()
plt.show()
